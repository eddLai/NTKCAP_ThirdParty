# %%
from Pose2Sim import Pose2Sim
import os
os.chdir(r'D:\NTKCAP_1.1.1\patient\patient_for_checking_pose2Sim\20230123\Apose\Empty_project')

Pose2Sim.personAssociation()
Pose2Sim.triangulation()
Pose2Sim.filtering()
# Out:
# ---------------------------------------------------------------------
# Tracking of the person of interest for Empty_project, for all frames.
# ---------------------------------------------------------------------
#
# Project directory: D:\NTKCAP_1.1.1\patient\patient_for_checking_pose2Sim\20230123\Apose\Empty_project
# 100%|██████████| 173/173 [00:00<00:00, 274.33it/s]
#
# --> Mean reprojection error for Neck point on all frames is 4.4 px, which roughly corresponds to 17.9 mm.
# --> In average, 0.0 cameras had to be excluded to reach the demanded None px error threshold.
#
# Tracked json files are stored in D:\NTKCAP_1.1.1\patient\patient_for_checking_pose2Sim\20230123\Apose\Empty_project\pose-2d-tracked.
# Tracking took 0.68 s.
#
#
# ---------------------------------------------------------------------
# Triangulation of 2D points for Empty_project, for all frames.
# ---------------------------------------------------------------------
#
# ...
